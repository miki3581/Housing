# %%
import pandas as pd
import kagglehub
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the style of the plots
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

# Downloading dataset from Kaggle
file_path = kagglehub.dataset_download("krzysztofjamroz/apartment-prices-in-poland", path="apartments_pl_2024_06.csv")

# Loading data into DataFrame
df = pd.read_csv(file_path)

df.head()
# Out:
#                                  id      city               type  \
# 0  811891f98a870dfd6e414374a0a85560  szczecin       blockOfFlats
# 1  adaf636d0c44d8d9325bce42403eefee  szczecin  apartmentBuilding
# 2  9b957bd60885a469c96f17b58a914f4b  szczecin  apartmentBuilding
# 3  74fef2ff7135bc70797a3fbfd7d44ed6  szczecin       blockOfFlats
# 4  77cc78c75b0d09bf84d6d3124a28803c  szczecin       blockOfFlats
#
#    squareMeters  rooms  floor  floorCount  buildYear   latitude  longitude  \
# 0         47.00    2.0    6.0        12.0     1981.0  53.428544  14.552812
# 1         88.22    3.0    1.0         2.0     2000.0  53.449093  14.516844
# 2        117.00    5.0    4.0         4.0        NaN  53.443096  14.561348
# 3         33.31    1.0    1.0         4.0     1963.0  53.436100  14.541200
# 4         56.00    3.0    7.0         7.0     2018.0  53.447465  14.557811
#
#    ...  pharmacyDistance    ownership  buildingMaterial  condition  \
# 0  ...             0.085  condominium      concreteSlab        NaN
# 1  ...             0.668  condominium             brick    premium
# 2  ...             0.229       udział             brick    premium
# 3  ...             0.388  cooperative             brick        NaN
# 4  ...             0.178  condominium             brick    premium
#
#    hasParkingSpace  hasBalcony  hasElevator  hasSecurity  hasStorageRoom  \
# 0               no         yes          yes           no             yes
# 1              yes         yes           no           no              no
# 2              yes         yes           no           no              no
# 3              yes          no           no          yes             yes
# 4              yes         yes          yes          yes             yes
#
#      price
# 0   449000
# 1   950000
# 2  1099000
# 3   380000
# 4   799000
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21501 entries, 0 to 21500
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    21501 non-null  str
#  1   city                  21501 non-null  str
#  2   type                  17104 non-null  str
#  3   squareMeters          21501 non-null  float64
#  4   rooms                 21501 non-null  float64
#  5   floor                 17928 non-null  float64
#  6   floorCount            21292 non-null  float64
#  7   buildYear             18121 non-null  float64
#  8   latitude              21501 non-null  float64
#  9   longitude             21501 non-null  float64
#  10  centreDistance        21501 non-null  float64
#  11  poiCount              21501 non-null  float64
#  12  schoolDistance        21490 non-null  float64
#  13  clinicDistance        21438 non-null  float64
#  14  postOfficeDistance    21481 non-null  float64
#  15  kindergartenDistance  21482 non-null  float64
#  16  restaurantDistance    21470 non-null  float64
#  17  collegeDistance       20917 non-null  float64
#  18  pharmacyDistance      21471 non-null  float64
#  19  ownership             21501 non-null  str
#  20  buildingMaterial      12709 non-null  str
#  21  condition             5580 non-null   str
#  22  hasParkingSpace       21501 non-null  str
#  23  hasBalcony            21501 non-null  str
#  24  hasElevator           20541 non-null  str
#  25  hasSecurity           21501 non-null  str
#  26  hasStorageRoom        21501 non-null  str
#  27  price                 21501 non-null  int64
# dtypes: float64(16), int64(1), str(11)
# memory usage: 4.6 MB

# %%
df.describe()
# Out:
#        squareMeters         rooms         floor    floorCount     buildYear  \
# count  21501.000000  21501.000000  17928.000000  21292.000000  18121.000000
# mean      56.968572      2.622948      3.404786      5.474826   1986.774129
# std       20.617717      0.892924      2.606225      3.407545     32.796668
# min       25.000000      1.000000      1.000000      1.000000   1850.000000
# 25%       42.690000      2.000000      2.000000      3.000000   1969.000000
# 50%       52.810000      3.000000      3.000000      4.000000   1993.000000
# 75%       66.300000      3.000000      4.000000      7.000000   2016.000000
# max      150.000000      6.000000     29.000000     29.000000   2024.000000
#
#            latitude     longitude  centreDistance      poiCount  \
# count  21501.000000  21501.000000    21501.000000  21501.000000
# mean      51.992750     19.496174        4.431978     20.542951
# std        1.313801      1.754150        2.783001     23.905646
# min       49.982066     14.447127        0.020000      0.000000
# 25%       51.103600     18.539977        2.130000      7.000000
# 50%       52.194157     19.914700        4.130000     14.000000
# 75%       52.379000     20.988591        6.250000     24.000000
# max       54.582870     23.208873       16.480000    212.000000
#
#        schoolDistance  clinicDistance  postOfficeDistance  \
# count    21490.000000    21438.000000        21481.000000
# mean         0.407994        0.970949            0.510007
# std          0.442670        0.882206            0.474219
# min          0.005000        0.005000            0.002000
# 25%          0.178000        0.361000            0.238000
# 50%          0.289000        0.677000            0.392000
# 75%          0.462000        1.244000            0.621000
# max          4.920000        4.918000            4.801000
#
#        kindergartenDistance  restaurantDistance  collegeDistance  \
# count          21482.000000        21470.000000     20917.000000
# mean               0.357013            0.335759         1.440711
# std                0.414213            0.433327         1.103795
# min                0.001000            0.001000         0.006000
# 25%                0.154000            0.112000         0.565000
# 50%                0.256000            0.224000         1.121000
# 75%                0.411000            0.402000         2.050000
# max                4.767000            4.928000         5.000000
#
#        pharmacyDistance         price
# count      21471.000000  2.150100e+04
# mean           0.347109  8.238679e+05
# std            0.427962  4.311267e+05
# min            0.001000  1.910000e+05
# 25%            0.136000  5.490000e+05
# 50%            0.235000  7.218240e+05
# 75%            0.403000  9.650000e+05
# max            4.802000  3.000000e+06

# %%
from data_loader import load_data

TARGET_CITY = 'warszawa'  
    
# Loading data
df = load_data()
    
# Filtering by city if specified
if TARGET_CITY:
    print(f"\nFiltering data exclusively for city: {TARGET_CITY.capitalize()}")
    df = df[df['city'] == TARGET_CITY].copy()
else:
    print("\nUsing the entire dataset (all cities).")
# Out:
# Filtering data exclusively for city: Warszawa

# %%
from preprocess import clean_data, engineer_features, encode_features

df_cleaned = clean_data(df)
df_engineered = engineer_features(df_cleaned)
df_encoded = encode_features(df_engineered)

# %%
df_encoded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 
# min          0.007000  ...           0.000000     0.000000       0.000000
# 25%          0.273000  ...           0.000000     0.000000       0.000000
# 50%          0.510000  ...           0.000000     0.000000       0.000000
# 75%          0.925750  ...           1.000000     0.000000       0.000000
# max          4.918000  ...           1.000000     1.000000       1.000000
#
#        ownership_cooperative  buildingMaterial_concreteSlab  \
# count            6962.000000                    6962.000000
# mean                0.123384                       0.127406
# std                 0.328901                       0.333451
# min                 0.000000                       0.000000
# 25%                 0.000000                       0.000000
# 50%                 0.000000                       0.000000
# 75%                 0.000000                       0.000000
# max                 1.000000                       1.000000
#
#        buildingMaterial_n/d  condition_n/d  condition_premium  hasElevator_no  \
# count           6962.000000    6962.000000        6962.000000     6962.000000
# mean               0.433640       0.746625           0.135880        0.304510
# std                0.495612       0.434975           0.342686        0.460233
# min                0.000000       0.000000           0.000000        0.000000
# 25%                0.000000       0.000000           0.000000        0.000000
# 50%                0.000000       1.000000           0.000000        0.000000
# 75%                1.000000       1.000000           0.000000        1.000000
# max                1.000000       1.000000           1.000000        1.000000
#
#        hasElevator_yes
# count      6962.000000
# mean          0.656851
# std           0.474795
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
#
# [8 rows x 29 columns]

# %%
from model import evaluate_with_cross_validation

print("\nPerforming 5-Fold Cross-Validation...")
cv_metrics = evaluate_with_cross_validation(df_encoded, target_col='price', n_splits=5)
print(f"Average MAE: {cv_metrics['MAE']:,.2f} PLN")
print(f"Average RMSE: {cv_metrics['RMSE']:,.2f} PLN")
print(f"Average R-squared (R2): {cv_metrics['R2']:.4f}")
# Out:
# Performing 5-Fold Cross-Validation...
# Average MAE: 138,208.53 PLN
# Average RMSE: 194,572.91 PLN
# Average R-squared (R2): 0.8270

# %%
from model import split_data, scale_data, train_linear_regression, evaluate_model, evaluate_feature_importance    
    
# Splitting data into train and test sets
X_train, X_test, y_train, y_test = split_data(df_encoded, target_col='price')
    
# Scaling numerical features
X_train_scaled, X_test_scaled = scale_data(X_train, X_test)

# Training Linear Regression model
model = train_linear_regression(X_train_scaled, y_train)

# Evaluating feature importance
importance_df = evaluate_feature_importance(model, X_train_scaled.columns)
    
print("\nTop 5 features that INCREASE the price most:")
print(importance_df.head(5).to_string(index=False))
    
print("\nTop 5 features that DECREASE the price most:")
print(importance_df.tail(5).to_string(index=False))
# Out:
# Top 5 features that INCREASE the price most:
#           Feature   Coefficient
#      squareMeters 418833.048999
# condition_premium  98215.725535
#  isNewDevelopment  89360.630088
#     condition_n/d  62885.297549
#   hasParkingSpace  29594.324003
#
# Top 5 features that DECREASE the price most:
#            Feature    Coefficient
#     centreDistance  -39755.589123
#              rooms  -41833.656628
# log_centreDistance  -53990.915212
#           type_n/d  -63343.864769
#  type_blockOfFlats -104736.246449
